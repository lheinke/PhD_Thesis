# %% [markdown]
# # Zotero

# %%
from pyzotero import zotero
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 from pyzotero import zotero
# ----> 2 from dotenv import load_dotenv
#       3 import os
#
# ModuleNotFoundError: No module named 'dotenv'

# %%
from dotenv import load_dotenv
import os

# Load .env file
load_dotenv()

API_KEY = os.getenv("ZOTERO_API_KEY")
LIB_ID = os.getenv("ZOTERO_LIBRARY_ID")
LIB_TYPE = os.getenv("ZOTERO_LIBRARY_TYPE", "user")

# %%
zot = zotero.Zotero(LIB_ID, LIB_TYPE, API_KEY)

# %%
items = zot.top(limit=5)
for item in items:
    print(f"Item: {item['data']['itemType']} | Key: {item['data']['key']}")
# Out:
# Item: journalArticle | Key: FPF27QES
# Item: journalArticle | Key: SD6XUQIN
# Item: journalArticle | Key: U86G8D5X
# Item: journalArticle | Key: HQYMGPN6
# Item: preprint | Key: 2RDUQG5S

# %%
item
# Out:
# {'key': '2RDUQG5S',
#  'version': 25425,
#  'library': {'type': 'user',
#   'id': 5883486,
#   'name': 'lheinke',
#   'links': {'alternate': {'href': 'https://www.zotero.org/lheinke',
#     'type': 'text/html'}}},
#  'links': {'self': {'href': 'https://api.zotero.org/users/5883486/items/2RDUQG5S',
#    'type': 'application/json'},
#   'alternate': {'href': 'https://www.zotero.org/lheinke/items/2RDUQG5S',
#    'type': 'text/html'}},
#  'meta': {'creatorSummary': 'Wang et al.',
#   'parsedDate': '2025-11-01',
#   'numChildren': 0},
#  'data': {'key': '2RDUQG5S',
#   'version': 25425,
#   'itemType': 'preprint',
#   'title': 'A Comprehensive Analysis of the Panchromatic Transmission Spectrum of the Hot-Saturn WASP-96 b: Nondetection of Haze, Possible Sodium Limb Asymmetry, Stellar Characterization, and Formation History',
#   'creators': [{'creatorType': 'author',
#     'firstName': 'Le-Chris',
#     'lastName': 'Wang'},
#    {'creatorType': 'author', 'firstName': 'Zafar', 'lastName': 'Rustamkulov'},
#    {'creatorType': 'author', 'firstName': 'David K.', 'lastName': 'Sing'},
#    {'creatorType': 'author', 'firstName': 'Joshua', 'lastName': 'Lothringer'},
#    {'creatorType': 'author', 'firstName': 'Patrick', 'lastName': 'McCreery'},
#    {'creatorType': 'author', 'firstName': 'Daniel', 'lastName': 'Thorngren'},
#    {'creatorType': 'author', 'firstName': 'Munazza K.', 'lastName': 'Alam'}],
#   'abstractNote': 'We conduct a reanalysis of the JWST NIRISS/SOSS observation of the hot-Saturn WASP-96 b. Initial analysis of this data revealed an enhanced Rayleigh scattering slope at the blue end of the transmission spectrum, suggesting the presence of hazes at high altitudes. In this work, we report non-detection of this slope, confirming an atmosphere clear of high-altitude aerosols consistent with the pre-JWST results. Also contrary to the initial result, our results indicate the presence of gray cloud deck, although at relatively low altitudes/high pressures. We further combined the NIRISS/SOSS spectrum with VLT, HST, and Spitzer to produce a transmission spectrum from 0.35 $μ$m to 5 $μ$m. We constrain the mass fraction of multiple chemical species, including: H$_2$O$=-2.62^{+0.43}_{-0.42}$, K$=-5.76^{+1.05}_{-1.13}$, and Na$=-3.40^{+0.90}_{-0.92}$. C/O ratio and metallicity are tentatively constrained at substellar values (C/O$_{planet}=0.57^{+0.07}_{-0.12}$ and [Fe/H]$_{planet}=0.01^{+0.46}_{-0.52}$ compared to C/O$_{star}=0.92\\pm0.25$ and [Fe/H]$_{star}=0.24\\pm0.05$). Inputing these composition constraints to interior models, we constrain a core mass of $43^{+8}_{-15}$ M$_\\oplus$. This, in addition to our inferred super-stellar refractory-to-oxygen ratio ($∆\\log_{10}(R/O)=1.48^{+0.57}_{-0.62}$) and substellar C/O ratio, suggests that the core of WASP-96 b likely formed outside of water iceline, underwent disk-driven migration, and accreted its atmosphere inside the carbon soot line. We find evidence of atmospheric leading-trailing terminator asymmetries in the broadened sodium absorption feature with a transit time offset of 50 seconds, while the water features appear symmetric. CH$_4$, CO, and CO$_2$ remain unconstrained due to spectral coverage limits. Upcoming JWST NIRSpec/G395H observations (ID 4082, PI: M. Radica) will be crucial for constraining these carbon-bearing species.',
#   'genre': '',
#   'repository': 'arXiv',
#   'archiveID': '',
#   'place': '',
#   'date': '2025-11-01',
#   'series': '',
#   'seriesNumber': '',
#   'DOI': '10.48550/arXiv.2511.16771',
#   'citationKey': '',
#   'url': 'https://ui.adsabs.harvard.edu/abs/2025arXiv251116771W',
#   'accessDate': '2025-12-01T19:59:14Z',
#   'archive': '',
#   'archiveLocation': '',
#   'shortTitle': 'A Comprehensive Analysis of the Panchromatic Transmission Spectrum of the Hot-Saturn WASP-96 b',
#   'language': '',
#   'libraryCatalog': 'NASA ADS',
#   'callNumber': '',
#   'rights': '',
#   'extra': 'ADS Bibcode: 2025arXiv251116771W',
#   'tags': [{'tag': 'Earth and Planetary Astrophysics', 'type': 1}],
#   'collections': ['HV9VS8ZD'],
#   'relations': {},
#   'dateAdded': '2025-12-01T19:59:14Z',
#   'dateModified': '2025-12-01T19:59:14Z'}}
